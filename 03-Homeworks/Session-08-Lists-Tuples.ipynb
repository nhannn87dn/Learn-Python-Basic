# %% [markdown]
# # Bài tập Session 06 - Lists - Tuples (Danh sách và Bộ dữ liệu)
#
# ## Phần 1: List
#
# **Câu 1:** Viết chương trình Python để tạo một danh sách chứa 5 số nguyên nhập từ người dùng.

# %% [markdown]
# **Câu 2:** Viết chương trình Python để tạo một danh sách chứa 5 chuỗi nhập từ người dùng.

# %% [markdown]
# **Câu 3:** Viết chương trình Python để tính tổng của tất cả các số trong danh sách số nguyên đã cho.
#
# ```python
# numbers = [1, 2, 2, 3, 4, 4, 5, 6, 7, 7, 8, 9, 10, 10]
# ```

# %% [markdown]
# **Câu 4:** Viết chương trình Python để tìm số lớn nhất trong danh sách số nguyên đã cho.
#
# ```python
# numbers = [1, 2, 2, 3, 4, 4, 5, 6, 7, 7, 8, 9, 10, 10]
# ```

# %% [markdown]
# **Câu 5:** Viết chương trình Python để sao chép tất cả các phần tử từ danh sách A sang danh sách B

# %% [markdown]
# **Câu 6:** Viết chương trình Python để đảo ngược danh sách đã cho (ví dụ: [1, 2, 3] -> [3, 2, 1]).
#
# ```python
# numbers = [1, 2, 2, 3, 4, 4, 5, 6, 7, 7, 8, 9, 10, 10]
# ```

# %% [markdown]
# **Câu 7:** Cho một danh sách như dưới đây. Viết một hàm trong Python để loại bỏ tất cả các số lặp lại trong danh sách số nguyên. In ra kết quả thực hiện.
#
# ```python
# numbers = [1, 2, 2, 3, 4, 4, 5, 6, 7, 7, 8, 9, 10, 10]
# ```

# %% [markdown]
# **Câu 8:** Cho một danh sách như dưới đây. Viết một hàm trong Python để tìm các số chẵn trong danh sách số nguyên. Sau đó in ra kết quả thực hiện
#
# ```python
# numbers = [1, 2, 2, 3, 4, 4, 5, 6, 7, 7, 8, 9, 10, 10]
# ```

# %% [markdown]
# ## Phần 2: Tuples
#
# **Câu 1:** Viết một chương trình Python để tạo một tuple chứa 5 số nguyên nhập từ người dùng

# %% [markdown]
# **Câu 2:** Tạo một **tuple** chứa các số từ `1` đến `5`.
# - In phần tử đầu tiên của tuple.
# - In phần tử cuối cùng của tuple.

# %% [markdown]
# **Câu 3:** Tạo một tuple chứa hai tuple khác, mỗi tuple chứa ba số nguyên.
# Truy cập và in phần tử thứ hai của tuple đầu tiên

# %% [markdown]
# **Câu 4:** Tạo hai tuple chứa các chữ cái.
# Nối hai tuple lại với nhau

# %% [markdown]
# **Câu 5:** Tạo một tuple chứa các số từ 1 đến 5.
# Sử dụng vòng lặp để in từng phần tử của tuple

# %% [markdown]
# **Câu 6:** Tạo một tuple chứa các số từ 1 đến 10.
# Viết một hàm Kiểm tra xem số `5` có tồn tại trong tuple không và in kết quả

# %% [markdown]
# **Câu 7:** Cho một Tuple như sau:
#
# ```python
# numbers = (1, 2, 3, 4, 5, 3, 6, 3, 7)
# ```
#
# Tìm và in chỉ số của phần tử đầu tiên có giá trị 3

# %% [markdown]
# **Câu 8:** Tạo một Tuple 5 bài hát bạn yêu thích và in nó ra.

# %% [markdown]
# ========================================
#
# CHỨC MỪNG ! BẠN ĐÃ VƯỢT QUA THỬ THÁCH BÀI TẬP !
#
# ## Cách nộp bài
#
# 1. Click vào liên kết **Share** phía góc trên bên phải
# 1. Tại dòng **General access**, đổi từ **Restricted** thành **Anyone with the link**
# 1. Click vào nút **Copy Link**, lấy link đó gửi cho giáo viên.
