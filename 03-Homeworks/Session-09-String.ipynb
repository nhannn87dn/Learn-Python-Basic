# %% [markdown]
# # Bài tập Session 09 - String (Chuỗi)
#
# **Câu 1:** Viết chương trình Python để nhập một chuỗi từ người dùng và in ra độ dài của chuỗi đó.

# %% [markdown]
# **Câu 2:** Viết chương trình Python để nhập một chuỗi từ người dùng và in ra chuỗi đó viết hoa (uppercase)

# %% [markdown]
# **Câu 3:** Viết chương trình Python để nhập một chuỗi từ người dùng và in ra chuỗi đó viết thường (lowercase)

# %% [markdown]
# **Câu 4:** Cho một chuỗi như dưới
#
# ```python
# sentence = "   Hello, world!   "
# ```
# Viết một hàm thực hiện xóa khoảng trống ở đầu và cuối chuỗi. Sau đó in kết quả việc thực hiện hàm với chuỗi trên.

# %% [markdown]
# **Câu 5:** Cho một chuỗi như dưới
#
# ```python
# sentence = "Hello, world!"
# ```
# Viết chương trình thay thế từ **"world"** thành **"Python"** và in kết quả

# %% [markdown]
# **Câu 6:** Cho chuỗi như bên dưới
#
# ```python
# sentence = "Hello world welcome to Python"
# ```
# Viết chương trình để tách chuỗi thành danh sách các từ và in kết quả

# %% [markdown]
# **Câu 7:**  Cho chuỗi như bên dưới
#
# ```python
# sentence = "Hello, world!"
# ```
#
# Viết hàm Kiểm tra xem trong chuỗi trên có chứa từ `world` không ?  Sau đó sử dụng hàm để kiểm tra chuỗi trên.

# %% [markdown]
# **Câu 8:** Cho chuỗi như bên dưới
#
# ```python
# mobile = '0988777666'
# ```
#
# Viết chương trình kiểm tra xem chuỗi đã cho có bắt đầu bằng "0988" không ? và in ra kết quả.

# %% [markdown]
# **Câu 9:** Cho chuỗi như bên dưới
#
# ```python
# mobile = '0988777666'
# ```
#
# Viết chương trình kiểm tra xem chuỗi đã cho có kết thúc bằng "666" không ? và in ra kết quả.

# %% [markdown]
# **Câu 10:** Tạo ba biến chứa tên, tuổi và thành phố của bạn.
#
# ```python
# name = 'Nguyen Van A'
# age = 18
# city = 'Danang'
# ```
# Viết chương trình để tạo một câu giới thiệu bản thân và in kết quả.
#
# ```python
# # Ví dụ: "Tên tôi là Nam. Tôi 25 tuổi và tôi đến từ Hà Nội."
# ```

# %% [markdown]
# **Câu 11:** Cho một biến chứa một số thực (float)
#
# ```python
# number = 123.456789
# ```
# Viết chương trình để in ra được kết quả
#
# ```python
# # Output: "Số đã được định dạng: 123.46"
# ```

# %% [markdown]
# **Câu 12:** Cho một số nguyên rất lớn như sau
#
# ```python
# large_number = 1234567890
# ```
# Viết chương trình định dạng số nguyên trên cho dễ nhìn. In ra được kết quả như sau
#
# ```python
# # Output: "Số đã được định dạng: 1,234,567,890"
# ```

# %% [markdown]
# ========================================
#
# CHỨC MỪNG ! BẠN ĐÃ VƯỢT QUA THỬ THÁCH BÀI TẬP !
#
# ## Cách nộp bài
#
# 1. Click vào liên kết **Share** phía góc trên bên phải
# 1. Tại dòng **General access**, đổi từ **Restricted** thành **Anyone with the link**
# 1. Click vào nút **Copy Link**, lấy link đó gửi cho giáo viên.
