# %% [markdown]
# # Bài tập Session 11 - Sets (Kiểu dữ liệu bộ)
#
#
# **Câu 1:** Viết chương trình Python để tạo một tập hợp chứa 5 số nguyên nhập từ người dùng.

# %% [markdown]
# **Câu 2:** Viết chương trình Python để tạo một tập hợp chứa 5 chuỗi nhập từ người dùng.

# %% [markdown]
# **Câu 3:** Viết chương trình Python để tính tổng của tất cả các số trong tập hợp số nguyên dưới đây.
#
# ```python
# integer_set = {1, 2, 3, 4, 5, 5, 6, 6, 7, 8, 9, 9}
# ```

# %% [markdown]
# **Câu 4:** Viết chương trình Python để tìm số lớn nhất trong tập hợp số nguyên đã cho ở Câu 3

# %% [markdown]
# **Câu 5:** Viết chương trình Python để nối hai tập hợp số nguyên thành một tập hợp mới.
#
# ```python
# integer_one = {1, 2, 3, 4, 5}
# integer_two = {6, 7, 8, 9, 9}
# ```

# %% [markdown]
# **Câu 6:** Viết chương trình Python để tìm các số chẵn trong tập hợp số nguyên tại câu 3 và trả về một tập hợp mới chứa các số đó

# %% [markdown]
# **Câu 7:** Viết chương trình Python để loại bỏ tất cả các số lặp lại trong tập hợp số nguyên ở câu 3.

# %% [markdown]
# **Câu 8:** Viết chương trình Python để tạo một tập hợp mới chứa các phần tử chỉ có trong một trong hai tập hợp đã cho (không có phần tử chung).
#
# ```python
# integer_one = {1, 2, 3, 4, 5}
# integer_two = {6, 7, 8, 9, 9,10}
# ```

# %% [markdown]
# **Câu 9:** Viết chương trình Python để kiểm tra xem một tập hợp `integer_two` có là tập hợp con của tập hợp `integer_one` hay không.
#
# ```python
# integer_one = {1, 2, 3, 4, 5,6, 7, 8, 9, 9,10}
# integer_two = {6, 7, 8, 9, 9,10}
# ```

# %% [markdown]
# **Câu 10:** Viết chương trình Python để kiểm tra xem hai tập hợp có phần tử chung hay không.
#
# ```python
# integer_one = {1, 2, 3, 4, 5,6, 7, 8, 9, 9,10}
# integer_two = {6, 7, 8, 9, 9,10}
# ```

# %% [markdown]
# ## Exception Handling
#
# **Câu 1:** Viết chương trình Python để yêu cầu người dùng nhập một số nguyên. Xử lý ngoại lệ nếu người dùng nhập không phải là một số nguyên.

# %% [markdown]
# **Câu 2:** Viết chương trình Python để yêu cầu người dùng nhập hai số và thực hiện phép chia của hai số đó. Xử lý ngoại lệ nếu người dùng nhập số thứ hai là 0 và trường hợp nhập vào không phải là số.

# %% [markdown]
# **Câu 3:** Viết chương trình Python để đọc nội dung của một tập tin văn bản. Xử lý ngoại lệ nếu tập tin không tồn tại hoặc không thể đọc được.

# %% [markdown]
# **Câu 4:** Viết chương trình Python để chia một số nguyên cho một danh sách các số. Xử lý ngoại lệ nếu có bất kỳ số nào trong danh sách là 0 hoặc không phải là số nguyên.

# %% [markdown]
# **Câu 5:** Viết chương trình Python để yêu cầu người dùng nhập một số và tính căn bậc hai của số đó. Xử lý ngoại lệ nếu người dùng nhập một số âm.

# %% [markdown]
# ========================================
#
# CHỨC MỪNG ! BẠN ĐÃ VƯỢT QUA THỬ THÁCH BÀI TẬP !
#
# ## Cách nộp bài
#
# 1. Click vào liên kết **Share** phía góc trên bên phải
# 1. Tại dòng **General access**, đổi từ **Restricted** thành **Anyone with the link**
# 1. Click vào nút **Copy Link**, lấy link đó gửi cho giáo viên.
