# %% [markdown]
# # Bài tập Session 09 - Dictionaries (Kiểu dữ liệu từ điển)
#
# **Câu 1:** Viết chương trình Python để tạo một từ điển chứa thông tin về một người, bao gồm tên, tuổi và địa chỉ. Sau đó in ra thông tin của người đó.

# %% [markdown]
# **Câu 2:** Viết chương trình Python để thêm một cặp key-value mới vào từ điển đã cho.
#
# ```python
# student = {
#     "name": "Nguyen Van A",
#     "age": 21,
#     "major": "Computer Science"
# }
# ```
# Thêm `mobile` với giá trị `0988777666`

# %% [markdown]
# **Câu 3:** Viết chương trình Python để xóa một key `major` khỏi từ điển đã cho.

# %% [markdown]
# **Câu 4:** Viết chương trình Python để in ra tất cả các key trong từ điển đã cho

# %% [markdown]
# **Câu 5:** Viết chương trình Python để in ra tất cả các value trong từ điển đã cho.

# %% [markdown]
# **Câu 6:** Viết chương trình Python để tính tổng của tất cả các giá trị số trong từ điển sau:
#
# ```python
# my_dict = {
#     "number_one": 1,
#     "number_two": 2,
#     "number_three": 3,
#     "number_four": "4",
#     "number_five": "55"
# }
# ```

# %% [markdown]
# **Câu 7:** Viết chương trình Python để kiểm tra xem một key cụ thể có tồn tại trong từ điển hay không.
#
# - Kiểm tra key: `age`
# - Kiểm tra key: `gender`

# %% [markdown]
# **Câu 8:** Viết chương trình Python để tạo một từ điển mới bằng cách sao chép toàn bộ nội dung từ một từ điển đã cho

# %% [markdown]
# **Câu 9:** Viết chương trình python để thay đổi giá trị của key `age` thành 18

# %% [markdown]
# **Câu 10:** Viết chương trình Python để xóa tất cả các cặp key-value khỏi từ điển

# %% [markdown]
# ========================================
#
# CHỨC MỪNG ! BẠN ĐÃ VƯỢT QUA THỬ THÁCH BÀI TẬP !
#
# ## Cách nộp bài
#
# 1. Click vào liên kết **Share** phía góc trên bên phải
# 1. Tại dòng **General access**, đổi từ **Restricted** thành **Anyone with the link**
# 1. Click vào nút **Copy Link**, lấy link đó gửi cho giáo viên.
